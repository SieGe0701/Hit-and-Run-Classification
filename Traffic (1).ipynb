# %%
import pandas as pd

# %%
data = pd.read_csv('Traffic.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183460 entries, 0 to 183459
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                183460 non-null  object
#  1   RD_NO                          179082 non-null  object
#  2   CRASH_DATE_EST_I               13728 non-null   object
#  3   CRASH_DATE                     183459 non-null  object
#  4   POSTED_SPEED_LIMIT             183459 non-null  float64
#  5   TRAFFIC_CONTROL_DEVICE         183459 non-null  object
#  6   DEVICE_CONDITION               183459 non-null  object
#  7   WEATHER_CONDITION              183459 non-null  object
#  8   LIGHTING_CONDITION             183459 non-null  object
#  9   FIRST_CRASH_TYPE               183459 non-null  object
#  10  TRAFFICWAY_TYPE                183459 non-null  object
#  11  LANE_CNT                       31 non-null      float64
# ...

# %%
data  = data.drop(['CRASH_RECORD_ID','RD_NO','CRASH_DATE_EST_I'],axis= 1)

# %%
data.head()
# Out:
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  06/28/2023 01:37:00 AM                30.0         TRAFFIC SIGNAL
# 1  06/28/2023 12:38:00 AM                25.0      STOP SIGN/FLASHER
# 2  06/28/2023 12:10:00 AM                30.0            NO CONTROLS
# 3  06/27/2023 11:45:00 PM                35.0            NO CONTROLS
# 4  06/27/2023 10:57:00 PM                30.0            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 0  FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 1  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
# 2           NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 3           NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 4           NO CONTROLS    FOG/SMOKE/HAZE  DARKNESS, LIGHTED ROAD
#
#                FIRST_CRASH_TYPE TRAFFICWAY_TYPE  LANE_CNT           ALIGNMENT  \
# ...

# %%
data = data.drop('LANE_CNT',axis = 1)

# %%
data.dropna(subset = ['HIT_AND_RUN_I'],inplace = True)

# %%
data
# Out:
#                     CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 1       06/28/2023 12:38:00 AM                25.0      STOP SIGN/FLASHER
# 4       06/27/2023 10:57:00 PM                30.0            NO CONTROLS
# 6       06/27/2023 10:04:00 PM                30.0            NO CONTROLS
# 7       06/27/2023 09:43:00 PM                30.0            NO CONTROLS
# 8       06/27/2023 09:30:00 PM                30.0            NO CONTROLS
# ...                        ...                 ...                    ...
# 183439  10/16/2021 04:27:00 PM                30.0            NO CONTROLS
# 183447  10/16/2021 04:00:00 PM                30.0         TRAFFIC SIGNAL
# 183448  10/16/2021 04:00:00 PM                30.0            NO CONTROLS
# 183452  10/16/2021 03:50:00 PM                30.0            NO CONTROLS
# 183458  10/16/2021 03:31:00 PM                45.0            NO CONTROLS
#
#             DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# ...

# %%
data.drop(['PHOTOS_TAKEN_I','STATEMENTS_TAKEN_I','DOORING_I','WORK_ZONE_I','WORK_ZONE_TYPE','WORKERS_PRESENT_I','NOT_RIGHT_OF_WAY_I'],axis = 1,inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62500 entries, 1 to 183458
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH_DATE                     62500 non-null  object
#  1   POSTED_SPEED_LIMIT             62500 non-null  float64
#  2   TRAFFIC_CONTROL_DEVICE         62500 non-null  object
#  3   DEVICE_CONDITION               62500 non-null  object
#  4   WEATHER_CONDITION              62500 non-null  object
#  5   LIGHTING_CONDITION             62500 non-null  object
#  6   FIRST_CRASH_TYPE               62500 non-null  object
#  7   TRAFFICWAY_TYPE                62500 non-null  object
#  8   ALIGNMENT                      62500 non-null  object
#  9   ROADWAY_SURFACE_COND           62500 non-null  object
#  10  ROAD_DEFECT                    62500 non-null  object
#  11  REPORT_TYPE                    60008 non-null  object
# ...

# %%
df = data.drop('INTERSECTION_RELATED_I',axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62500 entries, 1 to 183458
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH_DATE                     62500 non-null  object
#  1   POSTED_SPEED_LIMIT             62500 non-null  float64
#  2   TRAFFIC_CONTROL_DEVICE         62500 non-null  object
#  3   DEVICE_CONDITION               62500 non-null  object
#  4   WEATHER_CONDITION              62500 non-null  object
#  5   LIGHTING_CONDITION             62500 non-null  object
#  6   FIRST_CRASH_TYPE               62500 non-null  object
#  7   TRAFFICWAY_TYPE                62500 non-null  object
#  8   ALIGNMENT                      62500 non-null  object
#  9   ROADWAY_SURFACE_COND           62500 non-null  object
#  10  ROAD_DEFECT                    62500 non-null  object
#  11  REPORT_TYPE                    60008 non-null  object
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59519 entries, 1 to 183458
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH_DATE                     59519 non-null  object
#  1   POSTED_SPEED_LIMIT             59519 non-null  float64
#  2   TRAFFIC_CONTROL_DEVICE         59519 non-null  object
#  3   DEVICE_CONDITION               59519 non-null  object
#  4   WEATHER_CONDITION              59519 non-null  object
#  5   LIGHTING_CONDITION             59519 non-null  object
#  6   FIRST_CRASH_TYPE               59519 non-null  object
#  7   TRAFFICWAY_TYPE                59519 non-null  object
#  8   ALIGNMENT                      59519 non-null  object
#  9   ROADWAY_SURFACE_COND           59519 non-null  object
#  10  ROAD_DEFECT                    59519 non-null  object
#  11  REPORT_TYPE                    59519 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# CRASH_DATE                       0
# POSTED_SPEED_LIMIT               0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# REPORT_TYPE                      0
# CRASH_TYPE                       0
# HIT_AND_RUN_I                    0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# PRIM_CONTRIBUTORY_CAUSE          0
# SEC_CONTRIBUTORY_CAUSE           0
# STREET_NO                        0
# STREET_DIRECTION                 0
# STREET_NAME                      0
# BEAT_OF_OCCURRENCE               0
# NUM_UNITS                        0
# MOST_SEVERE_INJURY               0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# ...

# %%
df.to_csv('FINAL_CLEANED_TRAFFIC.csv')
